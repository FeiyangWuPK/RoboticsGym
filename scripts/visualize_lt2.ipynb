# %% [markdown]
# # Learn to Teach: visualization of the results

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ant-v4 LT2

# %%
# Load your numpy data
from matplotlib.pyplot import step


teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
plt.figure()
plt.plot(teacher_means, label='Teacher')
plt.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3)
plt.plot(student_means, label='Student')
plt.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3)
plt.xlabel('Env steps (in millions)')
plt.ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
plt.xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
plt.xticks(tick_locations, tick_labels)

plt.title("Ant-v4")
plt.legend()
plt.savefig("ant_rl.pdf")

# %%
# Load your numpy data
from matplotlib.pyplot import step


teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5 Student Learns from BC/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5 Student Learns from BC/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)


# Plotting
plt.figure()
plt.plot(teacher_means, label="Teacher")
plt.fill_between(
    range(len(teacher_means)),
    teacher_means - teacher_std_devs,
    teacher_means + teacher_std_devs,
    alpha=0.3,
)
plt.plot(student_means, label="Student")
student_best = student_means.copy()
student_best = np.ones(student_means.shape[0]) * 2744.751
plt.plot(student_best, linestyle='--', label='LT2 student best')
plt.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3)
plt.xlabel('Env steps (in millions)')
plt.ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
plt.xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
plt.xticks(tick_locations, tick_labels)

plt.title("Ant-v4")
plt.legend()
plt.savefig("ant_rl.pdf")

# %% [markdown]
# ## Half Cheetah LT2

# %%
# Load your numpy data
from matplotlib.pyplot import step


teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
plt.figure()
plt.plot(teacher_means, label='Teacher')
plt.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3)
plt.plot(student_means, label='Student')
plt.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3)
plt.xlabel('Env steps (in millions)')
plt.ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
plt.xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
plt.xticks(tick_locations, tick_labels)

plt.title("HalfCheetah-v4")
plt.legend()
# plt.show()
plt.savefig("halfcheetah_rl.pdf")

# %%
# Load your numpy data
from matplotlib.pyplot import step


teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5 Student Learns from BC/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5 Student Learns from BC/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
plt.figure()
plt.plot(teacher_means, label="Teacher")
plt.fill_between(
    range(len(teacher_means)),
    teacher_means - teacher_std_devs,
    teacher_means + teacher_std_devs,
    alpha=0.3,
)
plt.plot(student_means, label="Student")
student_best = student_means.copy()
student_best = np.ones(student_means.shape[0]) * 5875.349
plt.plot(student_best, linestyle='--', label='LT2 student best')
plt.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3)
plt.xlabel('Env steps (in millions)')
plt.ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
plt.xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
plt.xticks(tick_locations, tick_labels)

plt.title("HalfCheetah-v4")
plt.legend()
# plt.show()
plt.savefig("halfcheetah_rl.pdf")

# %% [markdown]
# ## Hopper-v4

# %%
# Load your numpy data
from matplotlib.pyplot import step


teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Hopper-v4 0.2/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Hopper-v4 0.2/student/evaluations.npz"
)["results"]
print(teacher_data.shape)

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
plt.figure()
plt.plot(teacher_means, label='Teacher')
plt.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3)
plt.plot(student_means, label='Student')
plt.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3)
plt.xlabel('Env steps (in millions)')
plt.ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
plt.xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
plt.xticks(tick_locations, tick_labels)

plt.title("Hopper-v4")
plt.legend()
plt.show()
# Out:
# (84, 5)

# %% [markdown]
# ## Walker2d

# %%
# Load your numpy data
from matplotlib.pyplot import step


teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Walker2d-v4 0.2/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Walker2d-v4 0.2/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
plt.figure()
plt.plot(teacher_means, label='Teacher')
plt.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3)
plt.plot(student_means, label='Student')
plt.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3)
plt.xlabel('Env steps (in millions)')
plt.ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
plt.xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
plt.xticks(tick_locations, tick_labels)

plt.title("Walker2d-v4")
plt.legend()
plt.show()

# %%
font_size = 20
plt.rcParams.update(
    {
        "font.size": font_size,
        "axes.titlesize": font_size + 2,
        "axes.labelsize": font_size,
        "xtick.labelsize": font_size - 2,
        "ytick.labelsize": font_size - 2,
        "legend.fontsize": font_size,
    }
)
instances = ['Ant-v4', 'HalfCheetah-v4', 'Hopper-v4', 'Walker2d-v4']
# Creating 6 plots in a 2x? grid
fig, axs = plt.subplots(2, 4, figsize=(32, 10))  # Adjust figsize as needed
axs_ant_rl, axs_halfcheetah_rl, axs_hopper_rl, axs_walker2d_rl = (
    axs[0, 0],
    axs[0, 1],
    axs[0, 2],
    axs[0, 3],
)
axs_ant_il, axs_halfcheetah_il, axs_hopper_il, axs_walker2d_il = (
    axs[1, 0],
    axs[1, 1],
    axs[1, 2],
    axs[1, 3],
)

# Ant-v4
# RL plot
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting axs_ant_rl

axs_ant_rl.plot(teacher_means, label='L2T-RL Teacher', c='#bd7ebe')
axs_ant_rl.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')
axs_ant_rl.plot(student_means, label='L2T-RL Student', c='#00bfa0')
axs_ant_rl.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3, color='#00bfa0')
axs_ant_rl.set_xlabel('Env steps (in millions)')
axs_ant_rl.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_ant_rl.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_ant_rl.set_xticks(tick_locations, tick_labels)

axs_ant_rl.set_title('Ant-v4')
axs_ant_rl.legend()

# IL plot
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5 Student Learns from BC/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Ant-v4 0.5 Student Learns from BC/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
axs_ant_il.plot(teacher_means, label='L2T-RL Teacher (best)', c='#bd7ebe')
axs_ant_il.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')

student_best = student_means.copy()
student_best = np.ones(student_means.shape[0]) * 2744.751
axs_ant_il.plot(student_best, linestyle='--', label='L2T-RL student (best)', c='#00bfa0',linewidth=5,)
axs_ant_il.plot(student_means, label='BC agent', c='darkorange')
axs_ant_il.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3, color='darkorange')
axs_ant_il.set_xlabel('Env steps (in millions)')
axs_ant_il.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_ant_il.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_ant_il.set_xticks(tick_locations, tick_labels)
axs_ant_il.legend()
# axs_ant_il.set_title('Ant-v4')

# Halfcheetah-v4
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)
student_max = student_means.max()
# Plotting axs_ant_rl

axs_halfcheetah_rl.plot(teacher_means, label='RL Teacher', c='#bd7ebe')
axs_halfcheetah_rl.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')
axs_halfcheetah_rl.plot(student_means, label='LT2 Student', c='#00bfa0')
axs_halfcheetah_rl.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3, color='#00bfa0')
axs_halfcheetah_rl.set_xlabel('Env steps (in millions)')
axs_halfcheetah_rl.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_halfcheetah_rl.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_halfcheetah_rl.set_xticks(tick_locations, tick_labels)

axs_halfcheetah_rl.set_title("HalfCheetah-v4")

# IL plot
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5 Student Learns from BC/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL HalfCheetah-v4 0.5 Student Learns from BC/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
axs_halfcheetah_il.plot(teacher_means, label='IL Teacher', c='#bd7ebe')
axs_halfcheetah_il.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')
axs_halfcheetah_il.plot(student_means, label='IL Student',c='darkorange')
student_best = student_means.copy()
student_best = np.ones(student_means.shape[0]) * student_max
axs_halfcheetah_il.plot(student_best, linestyle='--', label='LT2 student best',c='#00bfa0',linewidth=5,)
axs_halfcheetah_il.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3,color='darkorange')
axs_halfcheetah_il.set_xlabel('Env steps (in millions)')
axs_halfcheetah_il.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_halfcheetah_il.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_halfcheetah_il.set_xticks(tick_locations, tick_labels)

# axs_halfcheetah_il.set_title('HalfCheetah-v4')

# Hopper-v4
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Hopper-v4 0.5/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Hopper-v4 0.5/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)
student_max = student_means.max()
# Plotting axs_ant_rl

axs_hopper_rl.plot(teacher_means, label='RL Teacher', c='#bd7ebe')
axs_hopper_rl.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')
axs_hopper_rl.plot(student_means, label='L2T Student', c='#00bfa0')
axs_hopper_rl.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3, color='#00bfa0')
axs_hopper_rl.set_xlabel('Env steps (in millions)')
axs_hopper_rl.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_hopper_rl.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_hopper_rl.set_xticks(tick_locations, tick_labels)

axs_hopper_rl.set_title("Hopper-v4")
# axs_ant_rl.set_legend()

# IL plot
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Hopper-v4 0.5 Student Learns from BC/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Hopper-v4 0.5 Student Learns from BC/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
axs_hopper_il.plot(teacher_means, label='IL Teacher', c='#bd7ebe')
axs_hopper_il.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')
axs_hopper_il.plot(student_means, label='IL Student', c='darkorange')
student_best = student_means.copy()
student_best = np.ones(student_means.shape[0]) * student_max 
axs_hopper_il.plot(student_best, linestyle='--', label='L2T student best', c='#00bfa0',linewidth=5)
axs_hopper_il.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3,color='darkorange')
axs_hopper_il.set_xlabel('Env steps (in millions)')
axs_hopper_il.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_hopper_il.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_hopper_il.set_xticks(tick_locations, tick_labels)

# axs_hopper_il.set_title('Hopper-v4')

# Walker2d-v4
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Walker2d-v4 0.5/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Walker2d-v4 0.5/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)
student_max = student_means.max()

axs_walker2d_rl.plot(teacher_means, label='RL Teacher', c='#bd7ebe')
axs_walker2d_rl.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')
axs_walker2d_rl.plot(student_means, label='LT2 Student', c='#00bfa0')
axs_walker2d_rl.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3, color='#00bfa0')
axs_walker2d_rl.set_xlabel('Env steps (in millions)')
axs_walker2d_rl.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_walker2d_rl.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_walker2d_rl.set_xticks(tick_locations, tick_labels)

axs_walker2d_rl.set_title("Walker2d-v4")
# axs_ant_rl.set_legend()

# IL plot
teacher_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Walker2d-v4 0.5 Student Learns from BC/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Documents/Repositories/RoboticsGym/logs/ICML2024 Guided Learning MuJoCo RL/Mujoco RL Walker2d-v4 0.5 Student Learns from BC/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
axs_walker2d_il.plot(teacher_means, label='IL Teacher', c='#bd7ebe')
axs_walker2d_il.fill_between(range(len(teacher_means)), teacher_means - teacher_std_devs, teacher_means + teacher_std_devs, alpha=0.3, color='#bd7ebe')
axs_walker2d_il.plot(student_means, label='IL Student',c='darkorange')
student_best = student_means.copy()
student_best = np.ones(student_means.shape[0]) * student_max
axs_walker2d_il.plot(student_best, linestyle='--', label='LT2 student best', c='#00bfa0', linewidth=5,)
axs_walker2d_il.fill_between(range(len(student_means)), student_means - student_std_devs, student_means + student_std_devs, alpha=0.3,color='darkorange')
axs_walker2d_il.set_xlabel('Env steps (in millions)')
axs_walker2d_il.set_ylabel('Episodic return')

# Setting x-axis to display a scale from 0 to 1
axs_walker2d_il.set_xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 1, num_ticks)
axs_walker2d_il.set_xticks(tick_locations, tick_labels)

# axs_walker2d_il.set_title('Walker2d-v4')

# fig.legend()
plt.tight_layout()
# plt.show()
plt.savefig("mujoco_results.pdf")

# %% [markdown]
# ## Cassie IL

# %%
# Load your numpy data
from matplotlib.pyplot import step
from numpy import size

font_size = 20
plt.rcParams.update(
    {
        "font.size": font_size,
        "axes.titlesize": font_size + 2,
        "axes.labelsize": font_size,
        "xtick.labelsize": font_size - 2,
        "ytick.labelsize": font_size - 2,
        "legend.fontsize": font_size,
    }
)

teacher_data = np.load(
    "/home/feiyang/Repositories/RoboticsGym/logs/ICML2024 Guided Learning/Student imitating POMDP 0.1 w CL second stage/teacher/evaluations.npz"
)["results"]
student_data = np.load(
    "/home/feiyang/Repositories/RoboticsGym/logs/ICML2024 Guided Learning/Student imitating POMDP 0.1 w CL second stage/student/evaluations.npz"
)["results"]

# Calculate the mean and standard deviation for each row
teacher_means = np.mean(teacher_data, axis=1)
teacher_std_devs = np.std(teacher_data, axis=1)

student_means = np.mean(student_data, axis=1)
student_std_devs = np.std(student_data, axis=1)

# Plotting
plt.figure(dpi=200, figsize=(16, 10))
plt.plot(teacher_means, label="Teacher")
plt.fill_between(
    range(len(teacher_means)),
    teacher_means - teacher_std_devs,
    teacher_means + teacher_std_devs,
    alpha=0.3,
)
plt.plot(student_means, label="Imitation Agent")
student_best = student_means.copy()
student_best = np.ones(student_means.shape[0]) * 455.128
plt.plot(student_best, linestyle="--", label="LT2-IRL best")
plt.fill_between(
    range(len(student_means)),
    student_means - student_std_devs,
    student_means + student_std_devs,
    alpha=0.3,
)
plt.xlabel("Env steps (in millions)")
plt.ylabel("Episodic reward")

# Setting x-axis to display a scale from 0 to 1
plt.xlim(0, len(teacher_means) - 1)
num_ticks = 5  # You can change this for more or fewer ticks
tick_locations = np.linspace(0, len(teacher_means) - 1, num_ticks)
tick_labels = np.linspace(0, 5, num_ticks)
plt.xticks(tick_locations, tick_labels)

plt.title("Cassie Locomotion")
plt.legend()
plt.savefig("cassie_il.pdf")
